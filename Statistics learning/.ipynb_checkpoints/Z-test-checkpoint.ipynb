# %% [markdown]
# # Suppose the IQ scores in a population are normally distributed with a mean
# μ = 100 and standard deviation σ = 15.
#
# - A researcher wants to test whether a new drug has an effect on IQ levels.
# He selects a random sample of 20 patients, administers the drug, and records their IQ scores.
#
# - Using this sample data, perform a one-sample Z-test to determine whether the drug causes a significant difference in IQ levels at a chosen significance level (e.g., α = 0.05).

# %%
# !pip install statsmodels
from statsmodels.stats.weightstats import ztest
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\MOHANASUNDARAM.M\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.6 MB 653.6 kB/s eta 0:00:15
#      ---------------------------------------- 0.1/9.6 MB 372.4 kB/s eta 0:00:26
#       --------------------------------------- 0.1/9.6 MB 722.1 kB/s eta 0:00:14
#       --------------------------------------- 0.1/9.6 MB 722.1 kB/s eta 0:00:14
#       --------------------------------------- 0.1/9.6 MB 722.1 kB/s eta 0:00:14
#       --------------------------------------- 0.1/9.6 MB 722.1 kB/s eta 0:00:14
#       --------------------------------------- 0.2/9.6 MB 446.5 kB/s eta 0:00:22
#      - -------------------------------------- 0.2/9.6 MB 602.4 kB/s eta 0:00:16
# ...

# %%
# enter ID levels for 20 patients"

# %%
data = [88,92,94,94,96,97,97,97,99,99,105,109,109,109,110,112,112,113,114,115]

# %%
data
# Out:
# [88,
#  92,
#  94,
#  94,
#  96,
#  97,
#  97,
#  97,
#  99,
#  99,
#  105,
#  109,
#  109,
#  109,
#  110,
#  112,
#  112,
#  113,
#  114,
#  115]

# %%
ztest(data,value=100)
# in answer first is z-zcore and second is p value
# Out:
# (np.float64(1.5976240527147705), np.float64(0.11012667014384257))
