# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("medical_data_100.csv")
df
# Out:
#    Patient_ID   Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0        P001   Neha   40  Female          O-  Migraine   Dr. Reddy
# 1        P002  Meena   68  Female          O+    Asthma   Dr. Reddy
# 2        P003  Meena   31  Female          B+     Fever  Dr. Sharma
# 3        P004  Divya   60  Female          O+     Fever  Dr. Sharma
# 4        P005  Priya   67    Male          B+    Asthma   Dr. Mehta
# ..        ...    ...  ...     ...         ...       ...         ...
# 95       P096  Anita   75    Male          A-       Flu   Dr. Reddy
# 96       P097  Kumar   20    Male         AB-  Diabetes   Dr. Mehta
# 97       P098  Priya   19  Female          A+     Fever   Dr. Kumar
# 98       P099   Ravi   32  Female          O-    Asthma   Dr. Reddy
# 99       P100   Ravi   69    Male          A-       Flu   Dr. Reddy
#
#     Visit_Date
# 0   2025-02-06
# 1   2025-05-10
# 2   2025-07-08
# 3   2025-10-31
# 4   2025-10-22
# ..         ...
# 95  2025-08-18
# 96  2025-04-09
# 97  2025-04-06
# 98  2025-08-08
# 99  2025-09-04
#
# [100 rows x 8 columns]

# %%
sns.set()

# %%
sns.countplot(x="Diagnosis",data = df)
plt.show()

# %%
sns.countplot(x="Age", data=df)
plt.show()

# %%
sns.barplot(x="Name",y="Doctor",data=df)
# plt.title("Analysis of patient with doctor")
plt.show()

# %%
sns.histplot(df["Age"],bins=20)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 sns.histplot(df["Age"],bins=20)
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
sns.boxplot(x="Diagnosis",y="Visit_Date",data = df)
plt.show()

# %%
sns.scatterplot(x="Gender",y="Diagnosis",data = df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.kdeplot(df["Age"], fill=True)
plt.show()

# %%
sns.kdeplot(df["Age"],fill=True)
sns.set_style("darkgrid")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap = "coolwarm")
plt.show()
