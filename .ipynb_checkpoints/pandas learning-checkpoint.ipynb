# %%
import pandas as pd

# %%
df = pd.read_csv("medical_data_100.csv")

# %%
df
# Out:
#    Patient_ID   Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0        P001   Neha   40  Female          O-  Migraine   Dr. Reddy
# 1        P002  Meena   68  Female          O+    Asthma   Dr. Reddy
# 2        P003  Meena   31  Female          B+     Fever  Dr. Sharma
# 3        P004  Divya   60  Female          O+     Fever  Dr. Sharma
# 4        P005  Priya   67    Male          B+    Asthma   Dr. Mehta
# ..        ...    ...  ...     ...         ...       ...         ...
# 95       P096  Anita   75    Male          A-       Flu   Dr. Reddy
# 96       P097  Kumar   20    Male         AB-  Diabetes   Dr. Mehta
# 97       P098  Priya   19  Female          A+     Fever   Dr. Kumar
# 98       P099   Ravi   32  Female          O-    Asthma   Dr. Reddy
# 99       P100   Ravi   69    Male          A-       Flu   Dr. Reddy
#
#     Visit_Date
# 0   2025-02-06
# 1   2025-05-10
# 2   2025-07-08
# 3   2025-10-31
# 4   2025-10-22
# ..         ...
# 95  2025-08-18
# 96  2025-04-09
# ...

# %%
df.head()
# Out:
#   Patient_ID   Name  Age  Gender Blood_Group Diagnosis      Doctor  Visit_Date
# 0       P001   Neha   40  Female          O-  Migraine   Dr. Reddy  2025-02-06
# 1       P002  Meena   68  Female          O+    Asthma   Dr. Reddy  2025-05-10
# 2       P003  Meena   31  Female          B+     Fever  Dr. Sharma  2025-07-08
# 3       P004  Divya   60  Female          O+     Fever  Dr. Sharma  2025-10-31
# 4       P005  Priya   67    Male          B+    Asthma   Dr. Mehta  2025-10-22

# %%
df.tail()
# Out:
#    Patient_ID   Name  Age  Gender Blood_Group Diagnosis     Doctor  Visit_Date
# 95       P096  Anita   75    Male          A-       Flu  Dr. Reddy  2025-08-18
# 96       P097  Kumar   20    Male         AB-  Diabetes  Dr. Mehta  2025-04-09
# 97       P098  Priya   19  Female          A+     Fever  Dr. Kumar  2025-04-06
# 98       P099   Ravi   32  Female          O-    Asthma  Dr. Reddy  2025-08-08
# 99       P100   Ravi   69    Male          A-       Flu  Dr. Reddy  2025-09-04

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Name', 'Age', 'Gender', 'Blood_Group', 'Diagnosis',
#        'Doctor', 'Visit_Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Patient_ID   100 non-null    object
#  1   Name         100 non-null    object
#  2   Age          100 non-null    int64
#  3   Gender       100 non-null    object
#  4   Blood_Group  100 non-null    object
#  5   Diagnosis    100 non-null    object
#  6   Doctor       100 non-null    object
#  7   Visit_Date   100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
df["Age"]
# Out:
# 0     40
# 1     68
# 2     31
# 3     60
# 4     67
#       ..
# 95    75
# 96    20
# 97    19
# 98    32
# 99    69
# Name: Age, Length: 100, dtype: int64

# %%
df["Blood_Group"]
# Out:
# 0      O-
# 1      O+
# 2      B+
# 3      O+
# 4      B+
#      ...
# 95     A-
# 96    AB-
# 97     A+
# 98     O-
# 99     A-
# Name: Blood_Group, Length: 100, dtype: object

# %%
df["Blood_Group"].head()
# Out:
# 0    O-
# 1    O+
# 2    B+
# 3    O+
# 4    B+
# Name: Blood_Group, dtype: object

# %%
df[["Name","Age"]].tail()
# Out:
#      Name  Age
# 95  Anita   75
# 96  Kumar   20
# 97  Priya   19
# 98   Ravi   32
# 99   Ravi   69

# %%
df.loc[0]
# Out:
# Patient_ID           P001
# Name                 Neha
# Age                    40
# Gender             Female
# Blood_Group            O-
# Diagnosis        Migraine
# Doctor          Dr. Reddy
# Visit_Date     2025-02-06
# Name: 0, dtype: object

# %%
df.loc[50]
# Out:
# Patient_ID             P051
# Name                  Priya
# Age                      39
# Gender               Female
# Blood_Group             AB+
# Diagnosis      Hypertension
# Doctor           Dr. Sharma
# Visit_Date       2025-04-23
# Name: 50, dtype: object

# %%
df[df["Age"] > 40]
# Out:
#    Patient_ID    Name  Age  Gender Blood_Group     Diagnosis      Doctor  \
# 1        P002   Meena   68  Female          O+        Asthma   Dr. Reddy
# 3        P004   Divya   60  Female          O+         Fever  Dr. Sharma
# 4        P005   Priya   67    Male          B+        Asthma   Dr. Mehta
# 5        P006    Ravi   53    Male          A+           Flu   Dr. Mehta
# 6        P007   Priya   80  Female          A-         Fever   Dr. Mehta
# ..        ...     ...  ...     ...         ...           ...         ...
# 86       P087  Suresh   47    Male          A+      Migraine  Dr. Sharma
# 92       P093   Kumar   75  Female          A-        Asthma   Dr. Mehta
# 93       P094   Anita   47    Male          B-  Hypertension   Dr. Reddy
# 95       P096   Anita   75    Male          A-           Flu   Dr. Reddy
# 99       P100    Ravi   69    Male          A-           Flu   Dr. Reddy
#
#     Visit_Date
# 1   2025-05-10
# 3   2025-10-31
# 4   2025-10-22
# 5   2025-08-14
# ...

# %%
df[df["Diagnosis"] == "Fever"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[df["Diagnosis"] == "Fever"]
#
# NameError: name 'df' is not defined

# %%
df[df["Diagnosis"] == "Flu"]
# Out:
#    Patient_ID    Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 5        P006    Ravi   53    Male          A+       Flu   Dr. Mehta
# 21       P022   Kumar   66    Male          O-       Flu   Dr. Mehta
# 22       P023  Vikram   64    Male          O-       Flu   Dr. Kumar
# 24       P025  Suresh   71  Female          O+       Flu   Dr. Mehta
# 45       P046   Priya   43  Female          A+       Flu  Dr. Sharma
# 53       P054  Suresh   43    Male          O-       Flu   Dr. Mehta
# 60       P061    Neha   50    Male         AB-       Flu   Dr. Kumar
# 63       P064   Divya   35  Female          A+       Flu  Dr. Sharma
# 79       P080    Arun   33  Female          O+       Flu   Dr. Mehta
# 84       P085  Suresh   54    Male          B-       Flu   Dr. Reddy
# 87       P088   Kumar   36    Male         AB-       Flu   Dr. Mehta
# 94       P095   Meena   33    Male         AB+       Flu   Dr. Reddy
# 95       P096   Anita   75    Male          A-       Flu   Dr. Reddy
# ...

# %%
df[df["Gender"] == "Male"]
# Out:
#    Patient_ID    Name  Age Gender Blood_Group     Diagnosis      Doctor  \
# 4        P005   Priya   67   Male          B+        Asthma   Dr. Mehta
# 5        P006    Ravi   53   Male          A+           Flu   Dr. Mehta
# 8        P009   Kumar   47   Male          B+  Hypertension   Dr. Mehta
# 9        P010   Anita   73   Male          A-        Asthma   Dr. Mehta
# 10       P011  Suresh   70   Male          O+      Diabetes  Dr. Sharma
# 12       P013    Neha   30   Male         AB+      Migraine  Dr. Sharma
# 14       P015   Meena   73   Male          A+      Diabetes   Dr. Reddy
# 15       P016   Priya   22   Male          B+  Hypertension   Dr. Kumar
# 17       P018   Anita   56   Male          B+  Hypertension   Dr. Kumar
# 18       P019   Divya   56   Male          B+      Migraine  Dr. Sharma
# 19       P020  Vikram   29   Male          O+        Asthma  Dr. Sharma
# 20       P021  Suresh   51   Male          A-         Fever   Dr. Mehta
# ...

# %%
df[(df["Age"] > 40) & (df["Gender"] == "Male")]
# Out:
#    Patient_ID    Name  Age Gender Blood_Group     Diagnosis      Doctor  \
# 4        P005   Priya   67   Male          B+        Asthma   Dr. Mehta
# 5        P006    Ravi   53   Male          A+           Flu   Dr. Mehta
# 8        P009   Kumar   47   Male          B+  Hypertension   Dr. Mehta
# 9        P010   Anita   73   Male          A-        Asthma   Dr. Mehta
# 10       P011  Suresh   70   Male          O+      Diabetes  Dr. Sharma
# 14       P015   Meena   73   Male          A+      Diabetes   Dr. Reddy
# 17       P018   Anita   56   Male          B+  Hypertension   Dr. Kumar
# 18       P019   Divya   56   Male          B+      Migraine  Dr. Sharma
# 20       P021  Suresh   51   Male          A-         Fever   Dr. Mehta
# 21       P022   Kumar   66   Male          O-           Flu   Dr. Mehta
# 22       P023  Vikram   64   Male          O-           Flu   Dr. Kumar
# 30       P031    Neha   60   Male          O+        Asthma   Dr. Mehta
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID     0
# Name           0
# Age            0
# Gender         0
# Blood_Group    0
# Diagnosis      0
# Doctor         0
# Visit_Date     0
# dtype: int64

# %%
df.isnull()
# Out:
#     Patient_ID   Name    Age  Gender  Blood_Group  Diagnosis  Doctor  \
# 0        False  False  False   False        False      False   False
# 1        False  False  False   False        False      False   False
# 2        False  False  False   False        False      False   False
# 3        False  False  False   False        False      False   False
# 4        False  False  False   False        False      False   False
# ..         ...    ...    ...     ...          ...        ...     ...
# 95       False  False  False   False        False      False   False
# 96       False  False  False   False        False      False   False
# 97       False  False  False   False        False      False   False
# 98       False  False  False   False        False      False   False
# 99       False  False  False   False        False      False   False
#
#     Visit_Date
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 95       False
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID     0
# Name           0
# Age            0
# Gender         0
# Blood_Group    0
# Diagnosis      0
# Doctor         0
# Visit_Date     0
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
df.rename(columns={"Name":"Patient_Name"},inplace = True)

# %%
df
# Out:
#    Patient_ID Patient_Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0        P001         Neha   40  Female          O-  Migraine   Dr. Reddy
# 1        P002        Meena   68  Female          O+    Asthma   Dr. Reddy
# 2        P003        Meena   31  Female          B+     Fever  Dr. Sharma
# 3        P004        Divya   60  Female          O+     Fever  Dr. Sharma
# 4        P005        Priya   67    Male          B+    Asthma   Dr. Mehta
# ..        ...          ...  ...     ...         ...       ...         ...
# 95       P096        Anita   75    Male          A-       Flu   Dr. Reddy
# 96       P097        Kumar   20    Male         AB-  Diabetes   Dr. Mehta
# 97       P098        Priya   19  Female          A+     Fever   Dr. Kumar
# 98       P099         Ravi   32  Female          O-    Asthma   Dr. Reddy
# 99       P100         Ravi   69    Male          A-       Flu   Dr. Reddy
#
#     Visit_Date
# 0   2025-02-06
# 1   2025-05-10
# 2   2025-07-08
# ...

# %%
df.head()
# Out:
#   Patient_ID Patient_Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0       P001         Neha   40  Female          O-  Migraine   Dr. Reddy
# 1       P002        Meena   68  Female          O+    Asthma   Dr. Reddy
# 2       P003        Meena   31  Female          B+     Fever  Dr. Sharma
# 3       P004        Divya   60  Female          O+     Fever  Dr. Sharma
# 4       P005        Priya   67    Male          B+    Asthma   Dr. Mehta
#
#    Visit_Date
# 0  2025-02-06
# 1  2025-05-10
# 2  2025-07-08
# 3  2025-10-31
# 4  2025-10-22

# %%
df["Age"].mean()
# Out:
# np.float64(48.11)

# %%
df["Gender"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df["Gender"].mean()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)
#    6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)
#   12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %%
df["Age"].sum()
# Out:
# np.int64(4811)

# %%
df["Age"].max()
# Out:
# np.int64(80)

# %%
df["Age"].min()
# Out:
# np.int64(19)

# %%
df.describe()
# Out:
#               Age
# count  100.000000
# mean    48.110000
# std     17.623386
# min     19.000000
# 25%     32.000000
# 50%     48.000000
# 75%     64.000000
# max     80.000000

# %%
df.groupby("Diagnosis")["Age"].mean()
# Out:
# Diagnosis
# Asthma          47.777778
# Diabetes        54.625000
# Fever           43.100000
# Flu             51.785714
# Hypertension    46.000000
# Migraine        47.000000
# Name: Age, dtype: float64

# %%
df.groupby("Visit_Date")["Age"].mean()
# Out:
# Visit_Date
# 2025-01-02    20.0
# 2025-01-03    49.0
# 2025-01-15    64.0
# 2025-01-16    70.0
# 2025-01-23    43.0
#               ...
# 2025-12-14    59.0
# 2025-12-16    41.0
# 2025-12-26    51.0
# 2025-12-27    56.0
# 2026-01-01    36.0
# Name: Age, Length: 91, dtype: float64

# %%
df.groupby("Diagnosis")["Blood_Group"]

# %%
df.sort_values("Age",ascending=False)
# Out:
#    Patient_ID Patient_Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 6        P007        Priya   80  Female          A-     Fever   Dr. Mehta
# 69       P070        Anita   79    Male          B+    Asthma   Dr. Mehta
# 33       P034        Meena   77  Female          B-    Asthma  Dr. Sharma
# 27       P028        Meena   77  Female         AB+     Fever   Dr. Reddy
# 95       P096        Anita   75    Male          A-       Flu   Dr. Reddy
# ..        ...          ...  ...     ...         ...       ...         ...
# 89       P090        Kumar   20    Male          A-    Asthma   Dr. Mehta
# 90       P091        Anita   20  Female         AB+  Migraine  Dr. Sharma
# 48       P049        Divya   19    Male          A-    Asthma   Dr. Mehta
# 88       P089       Suresh   19  Female          A-    Asthma  Dr. Sharma
# 97       P098        Priya   19  Female          A+     Fever   Dr. Kumar
#
#     Visit_Date
# 6   2025-07-31
# 69  2025-09-17
# 33  2025-02-16
# ...

# %%
df.sort("Age")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21316\449842693.py in ?()
# ----> 1 df.sort("Age")
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
df.sort("Age", ascending=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21316\2222244977.py in ?()
# ----> 1 df.sort("Age", ascending=True)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
df.sort_values("Age")
# Out:
#    Patient_ID Patient_Name  Age  Gender Blood_Group     Diagnosis      Doctor  \
# 48       P049        Divya   19    Male          A-        Asthma   Dr. Mehta
# 88       P089       Suresh   19  Female          A-        Asthma  Dr. Sharma
# 97       P098        Priya   19  Female          A+         Fever   Dr. Kumar
# 82       P083        Priya   20  Female         AB+  Hypertension   Dr. Kumar
# 90       P091        Anita   20  Female         AB+      Migraine  Dr. Sharma
# ..        ...          ...  ...     ...         ...           ...         ...
# 92       P093        Kumar   75  Female          A-        Asthma   Dr. Mehta
# 27       P028        Meena   77  Female         AB+         Fever   Dr. Reddy
# 33       P034        Meena   77  Female          B-        Asthma  Dr. Sharma
# 69       P070        Anita   79    Male          B+        Asthma   Dr. Mehta
# 6        P007        Priya   80  Female          A-         Fever   Dr. Mehta
#
#     Visit_Date
# 48  2025-04-06
# ...

# %%
df["Age"].value_counts()
# Out:
# Age
# 47    5
# 56    5
# 31    4
# 36    4
# 20    4
# 26    4
# 52    3
# 66    3
# 64    3
# 35    3
# 19    3
# 70    3
# 32    3
# 69    3
# 41    3
# 28    2
# 77    2
# 33    2
# 75    2
# 43    2
# 67    2
# 73    2
# 30    2
# 60    2
# 68    2
# 53    2
# 50    2
# 61    2
# 74    2
# 29    2
# 40    1
# 22    1
# 37    1
# 49    1
# 80    1
# 34    1
# 55    1
# 51    1
# 71    1
# 46    1
# 57    1
# 39    1
# 79    1
# 59    1
# 58    1
# 27    1
# 54    1
# Name: count, dtype: int64

# %%
df["Blood_Group"].value_counts()
# Out:
# Blood_Group
# O+     18
# A-     15
# B+     14
# AB+    13
# A+     11
# O-     10
# AB-    10
# B-      9
# Name: count, dtype: int64
