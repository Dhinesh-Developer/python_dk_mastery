# %% [markdown]
# ## Chapter 1: Getting and knowing your data
# - step 1: give a suitable name for the dataset
# - step 2: business understanding like benefits and disadvantages
# - step 3: data collections
# - step 4 : data understanding
# - step 5: Data preparation -> Data Cleaning

# %%
import pandas as pd

# %%
order_details = pd.read_csv(filepath_or_buffer = "data.tsv.txt",sep = "\t")

# %%
pd.read_csv(filepath_or_buffer = "medical_data_100.csv",sep=",")
# Out:
#    Patient_ID   Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0        P001   Neha   40  Female          O-  Migraine   Dr. Reddy
# 1        P002  Meena   68  Female          O+    Asthma   Dr. Reddy
# 2        P003  Meena   31  Female          B+     Fever  Dr. Sharma
# 3        P004  Divya   60  Female          O+     Fever  Dr. Sharma
# 4        P005  Priya   67    Male          B+    Asthma   Dr. Mehta
# ..        ...    ...  ...     ...         ...       ...         ...
# 95       P096  Anita   75    Male          A-       Flu   Dr. Reddy
# 96       P097  Kumar   20    Male         AB-  Diabetes   Dr. Mehta
# 97       P098  Priya   19  Female          A+     Fever   Dr. Kumar
# 98       P099   Ravi   32  Female          O-    Asthma   Dr. Reddy
# 99       P100   Ravi   69    Male          A-       Flu   Dr. Reddy
#
#     Visit_Date
# 0   2025-02-06
# 1   2025-05-10
# 2   2025-07-08
# 3   2025-10-31
# 4   2025-10-22
# ..         ...
# 95  2025-08-18
# 96  2025-04-09
# ...

# %% [markdown]
# ##### insights(client data) -or- meaning insights (me identified and tell to client)

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### 1.1Perform initail Analysis
# - shape
# - null entrires check
# - describe
# - dtype check

# %%
# function -> always end with open and close bracket
# Attribute -> it does not return any value
order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# #### Terminalogy alert
# - rows - observation/Record
# - columns - features/Parameters

# %%
order_details.isnull().sum() # find the null values , #chain of functions
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# very important function describitive values
order_details.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
order_details.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# ## 1.2 Find out the items sold in the restaurent

# %%
order_details.nunique() # find the unique data
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
order_details["item_name"]
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
order_details["item_name"].unique() # finding all the items name in the dataset
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %% [markdown]
# ## 1.3 Give me the list of Top 5 selling item

# %%
order_details.groupby(by="item_name")["quantity"].sum().sort_values()
# Out:
# item_name
# Carnitas Salad                             1
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Bowl                                       4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Veggie Soft Tacos                          8
# Carnitas Crispy Tacos                      8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Chips and Roasted Chili-Corn Salsa        18
# Veggie Salad Bowl                         18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# ...

# %%
order_details.sort_values(by="quantity",ascending=False)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 4152      1660        10                 Bottled Water
# 3887      1559         8                 Side of Chips
# 3599      1443         7                 Bottled Water
# 2441       970         5                 Bottled Water
# ...        ...       ...                           ...
# 4617      1833         1                 Steak Burrito
# 4618      1833         1                 Steak Burrito
# 4619      1834         1            Chicken Salad Bowl
# 4620      1834         1            Chicken Salad Bowl
# 29          15         1               Chicken Burrito
#
#                                      choice_description item_price
# 3598                                                NaN    $44.25
# 4152                                                NaN    $15.00
# 3887                                                NaN    $13.52
# ...

# %%
order_details.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order_details.groupby(by="item_name")["quantity"].sum().sort_values(ascending=False).head(10)
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %% [markdown]
# ## Give me the list of least 5 selling items

# %%
order_details.groupby(by="item_name")["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Chapter 2 : Data Cleaning

# %%
# Data preparation ->

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# clearing the $ symbol in item_price,# using slicing concept to clear the $ symbol
# this is not working
order_details["item_price"].replace(to_replace="$",value="",inplace=True)

# %%
# This is working.
order_details["item_price"].str.replace("$","").float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23328\1705149246.py in ?()
#       1 # This is working.
# ----> 2 order_details["item_price"].str.replace("$","").float()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float'

# %%
# series

# %%
# This is working. and store this is dataset
order_details["item_price"] = order_details["item_price"].str.replace("$","").astype(float)

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ##  Task :
# 1. Find out the top 5 selling item individual Revenue it made.
# 2. Total Revenue of the top 5 items sold.
# 3. find two more questions on the same dataset

# %%
order_details.groupby("item_name")["item_price"].sum().sort_values(ascending=False).value_counts().head(5)
# Out:
# item_price
# 14.80      2
# 5575.82    1
# 3851.43    1
# 2260.19    1
# 2201.04    1
# Name: count, dtype: int64

# %% [markdown]
# ###  Chapter 3: - Pandas Data structure
# - 1D - series
# - 2D - DataFrame

# %%
# always return index with values
pd.Series(data=[1,2,3,4,"$5.6"])
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4    $5.6
# dtype: object

# %%
pd.DataFrame(data={"Names":["Vijay","Ajay","kumar","sri","mirudula"],"Math":[67,78,32,65,56],"Science":[54,65,87,87,98],"Social":[100,90,34,65,34]})
# Out:
#       Names  Math  Science  Social
# 0     Vijay    67       54     100
# 1      Ajay    78       65      90
# 2     kumar    32       87      34
# 3       sri    65       87      65
# 4  mirudula    56       98      34

# %% [markdown]
# ## Task:
# 1. create a meaningful Serires
# 2. create a meaningful dataset using pandas Dataframe with Dict 5 Observations across 6 features

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# ## Chapter 4 -> Filtering, selection and sorting

# %%
euro_data = pd.read_csv("Euro_2012_stats_TEAM.csv")
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_data
