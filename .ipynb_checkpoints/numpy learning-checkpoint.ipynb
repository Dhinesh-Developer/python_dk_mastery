# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("medical_data_100.csv")

# %%
df
# Out:
#    Patient_ID   Name  Age  Gender Blood_Group Diagnosis      Doctor  \
# 0        P001   Neha   40  Female          O-  Migraine   Dr. Reddy
# 1        P002  Meena   68  Female          O+    Asthma   Dr. Reddy
# 2        P003  Meena   31  Female          B+     Fever  Dr. Sharma
# 3        P004  Divya   60  Female          O+     Fever  Dr. Sharma
# 4        P005  Priya   67    Male          B+    Asthma   Dr. Mehta
# ..        ...    ...  ...     ...         ...       ...         ...
# 95       P096  Anita   75    Male          A-       Flu   Dr. Reddy
# 96       P097  Kumar   20    Male         AB-  Diabetes   Dr. Mehta
# 97       P098  Priya   19  Female          A+     Fever   Dr. Kumar
# 98       P099   Ravi   32  Female          O-    Asthma   Dr. Reddy
# 99       P100   Ravi   69    Male          A-       Flu   Dr. Reddy
#
#     Visit_Date
# 0   2025-02-06
# 1   2025-05-10
# 2   2025-07-08
# 3   2025-10-31
# 4   2025-10-22
# ..         ...
# 95  2025-08-18
# 96  2025-04-09
# ...

# %%
data = df.values

# %%
data
# Out:
# array([['P001', 'Neha', 40, 'Female', 'O-', 'Migraine', 'Dr. Reddy',
#         '2025-02-06'],
#        ['P002', 'Meena', 68, 'Female', 'O+', 'Asthma', 'Dr. Reddy',
#         '2025-05-10'],
#        ['P003', 'Meena', 31, 'Female', 'B+', 'Fever', 'Dr. Sharma',
#         '2025-07-08'],
#        ['P004', 'Divya', 60, 'Female', 'O+', 'Fever', 'Dr. Sharma',
#         '2025-10-31'],
#        ['P005', 'Priya', 67, 'Male', 'B+', 'Asthma', 'Dr. Mehta',
#         '2025-10-22'],
#        ['P006', 'Ravi', 53, 'Male', 'A+', 'Flu', 'Dr. Mehta',
#         '2025-08-14'],
#        ['P007', 'Priya', 80, 'Female', 'A-', 'Fever', 'Dr. Mehta',
#         '2025-07-31'],
#        ['P008', 'Neha', 52, 'Female', 'O+', 'Migraine', 'Dr. Mehta',
#         '2025-11-09'],
#        ['P009', 'Kumar', 47, 'Male', 'B+', 'Hypertension', 'Dr. Mehta',
#         '2025-11-17'],
#        ['P010', 'Anita', 73, 'Male', 'A-', 'Asthma', 'Dr. Mehta',
#         '2025-07-09'],
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.shape # finding the no.of rows and columns
# Out:
# (100, 8)

# %%
data.size # row * columns ->
# Out:
# 800

# %%
data.dtype
# Out:
# dtype('O')

# %%
data.nbytes
# Out:
# 6400

# %%
age = df["Age"].to_numpy() # converting to column values to array values

# %%
age
# Out:
# array([40, 68, 31, 60, 67, 53, 80, 52, 47, 73, 70, 49, 30, 37, 73, 22, 47,
#        56, 56, 29, 51, 66, 64, 66, 71, 74, 61, 77, 55, 28, 60, 50, 26, 77,
#        31, 64, 26, 26, 28, 26, 30, 47, 68, 34, 31, 43, 52, 31, 19, 57, 39,
#        56, 74, 43, 41, 36, 70, 41, 29, 36, 50, 32, 52, 35, 36, 53, 35, 46,
#        69, 79, 67, 64, 58, 69, 56, 70, 61, 41, 59, 33, 27, 32, 20, 56, 54,
#        66, 47, 36, 19, 20, 20, 35, 75, 47, 33, 75, 20, 19, 32, 69])

# %%
blood_group = df["Blood_Group"].to_numpy()

# %%
blood_group
# Out:
# array(['O-', 'O+', 'B+', 'O+', 'B+', 'A+', 'A-', 'O+', 'B+', 'A-', 'O+',
#        'A+', 'AB+', 'O-', 'A+', 'B+', 'O+', 'B+', 'B+', 'O+', 'A-', 'O-',
#        'O-', 'AB+', 'O+', 'O+', 'B+', 'AB+', 'B-', 'O+', 'O+', 'B+',
#        'AB-', 'B-', 'B+', 'B+', 'O+', 'A-', 'AB-', 'O+', 'O+', 'AB+',
#        'AB-', 'AB+', 'O+', 'A+', 'A+', 'A+', 'A-', 'A-', 'AB+', 'B+',
#        'B-', 'O-', 'O-', 'B+', 'AB+', 'AB+', 'B-', 'AB+', 'AB-', 'B+',
#        'O-', 'A+', 'AB+', 'B-', 'AB-', 'O+', 'A-', 'B+', 'AB-', 'A+',
#        'B-', 'A-', 'O+', 'A+', 'B-', 'O-', 'AB-', 'O+', 'O-', 'A-', 'AB+',
#        'O+', 'B-', 'AB-', 'A+', 'AB-', 'A-', 'A-', 'AB+', 'A-', 'A-',
#        'B-', 'AB+', 'A-', 'AB-', 'A+', 'O-', 'A-'], dtype=object)

# %%
np.mean("Age")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 np.mean("Age")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\_methods.py:135, in _mean(a, axis, dtype, out, keepdims, where)
#     132         dtype = mu.dtype('f4')
#     133         is_float16_result = True
# --> 135 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     136 if isinstance(ret, mu.ndarray):
#     137     ret = um.true_divide(
# ...

# %%
np.mean(age)
# Out:
# np.float64(48.11)

# %%
age[age > 50]
# Out:
# array([68, 60, 67, 53, 80, 52, 73, 70, 73, 56, 56, 51, 66, 64, 66, 71, 74,
#        61, 77, 55, 60, 77, 64, 68, 52, 57, 56, 74, 70, 52, 53, 69, 79, 67,
#        64, 58, 69, 56, 70, 61, 59, 56, 54, 66, 75, 75, 69])

# %%
blood_group[blood_group == 'O+']
# Out:
# array(['O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+',
#        'O+', 'O+', 'O+', 'O+', 'O+', 'O+', 'O+'], dtype=object)

# %%
diagnosis = df["Diagnosis"].to_numpy()

# %%
diagnosis
# Out:
# array(['Migraine', 'Asthma', 'Fever', 'Fever', 'Asthma', 'Flu', 'Fever',
#        'Migraine', 'Hypertension', 'Asthma', 'Diabetes', 'Hypertension',
#        'Migraine', 'Asthma', 'Diabetes', 'Hypertension', 'Migraine',
#        'Hypertension', 'Migraine', 'Asthma', 'Fever', 'Flu', 'Flu',
#        'Diabetes', 'Flu', 'Migraine', 'Diabetes', 'Fever', 'Asthma',
#        'Hypertension', 'Asthma', 'Diabetes', 'Asthma', 'Asthma',
#        'Diabetes', 'Diabetes', 'Fever', 'Fever', 'Fever', 'Fever',
#        'Migraine', 'Diabetes', 'Migraine', 'Fever', 'Fever', 'Flu',
#        'Migraine', 'Hypertension', 'Asthma', 'Diabetes', 'Hypertension',
#        'Fever', 'Migraine', 'Flu', 'Hypertension', 'Asthma', 'Diabetes',
#        'Migraine', 'Fever', 'Migraine', 'Flu', 'Fever', 'Migraine', 'Flu',
#        'Migraine', 'Asthma', 'Asthma', 'Diabetes', 'Hypertension',
#        'Asthma', 'Fever', 'Fever', 'Diabetes', 'Hypertension', 'Migraine',
# ...

# %%
diagnosis[diagnosis == 'Fever']
# Out:
# array(['Fever', 'Fever', 'Fever', 'Fever', 'Fever', 'Fever', 'Fever',
#        'Fever', 'Fever', 'Fever', 'Fever', 'Fever', 'Fever', 'Fever',
#        'Fever', 'Fever', 'Fever', 'Fever', 'Fever', 'Fever'], dtype=object)

# %%
data[0]
# Out:
# array(['P001', 'Neha', 40, 'Female', 'O-', 'Migraine', 'Dr. Reddy',
#        '2025-02-06'], dtype=object)

# %%
data[0:5]
# Out:
# array([['P001', 'Neha', 40, 'Female', 'O-', 'Migraine', 'Dr. Reddy',
#         '2025-02-06'],
#        ['P002', 'Meena', 68, 'Female', 'O+', 'Asthma', 'Dr. Reddy',
#         '2025-05-10'],
#        ['P003', 'Meena', 31, 'Female', 'B+', 'Fever', 'Dr. Sharma',
#         '2025-07-08'],
#        ['P004', 'Divya', 60, 'Female', 'O+', 'Fever', 'Dr. Sharma',
#         '2025-10-31'],
#        ['P005', 'Priya', 67, 'Male', 'B+', 'Asthma', 'Dr. Mehta',
#         '2025-10-22']], dtype=object)

# %%
data[:,2]
# Out:
# array([40, 68, 31, 60, 67, 53, 80, 52, 47, 73, 70, 49, 30, 37, 73, 22, 47,
#        56, 56, 29, 51, 66, 64, 66, 71, 74, 61, 77, 55, 28, 60, 50, 26, 77,
#        31, 64, 26, 26, 28, 26, 30, 47, 68, 34, 31, 43, 52, 31, 19, 57, 39,
#        56, 74, 43, 41, 36, 70, 41, 29, 36, 50, 32, 52, 35, 36, 53, 35, 46,
#        69, 79, 67, 64, 58, 69, 56, 70, 61, 41, 59, 33, 27, 32, 20, 56, 54,
#        66, 47, 36, 19, 20, 20, 35, 75, 47, 33, 75, 20, 19, 32, 69],
#       dtype=object)

# %%
age.mean()
# Out:
# np.float64(48.11)

# %%
age.max()
# Out:
# np.int64(80)

# %%
age.min()
# Out:
# np.int64(19)

# %%
age[(age>50) & (age < 60)]
# Out:
# array([53, 52, 56, 56, 51, 55, 52, 57, 56, 52, 53, 58, 56, 59, 56, 54])

# %%
data[0:10]
# Out:
# array([['P001', 'Neha', 40, 'Female', 'O-', 'Migraine', 'Dr. Reddy',
#         '2025-02-06'],
#        ['P002', 'Meena', 68, 'Female', 'O+', 'Asthma', 'Dr. Reddy',
#         '2025-05-10'],
#        ['P003', 'Meena', 31, 'Female', 'B+', 'Fever', 'Dr. Sharma',
#         '2025-07-08'],
#        ['P004', 'Divya', 60, 'Female', 'O+', 'Fever', 'Dr. Sharma',
#         '2025-10-31'],
#        ['P005', 'Priya', 67, 'Male', 'B+', 'Asthma', 'Dr. Mehta',
#         '2025-10-22'],
#        ['P006', 'Ravi', 53, 'Male', 'A+', 'Flu', 'Dr. Mehta',
#         '2025-08-14'],
#        ['P007', 'Priya', 80, 'Female', 'A-', 'Fever', 'Dr. Mehta',
#         '2025-07-31'],
#        ['P008', 'Neha', 52, 'Female', 'O+', 'Migraine', 'Dr. Mehta',
#         '2025-11-09'],
#        ['P009', 'Kumar', 47, 'Male', 'B+', 'Hypertension', 'Dr. Mehta',
#         '2025-11-17'],
#        ['P010', 'Anita', 73, 'Male', 'A-', 'Asthma', 'Dr. Mehta',
#         '2025-07-09']], dtype=object)

# %%
arr = np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr = np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
