# %%
--- CEO roles
-trainer
-content writer
-video editing
-sales
-graphics designer

# %%
#Data structures
#lists,tuples,dictonaries,sets

# %% [markdown]
# ## Why python data structures
# -To collect multiple data in a structure

# %% [markdown]
# ### LIST
# - list accepts duplicates values
# - list is mutable
# - slicing can be done
# - list is hetergoneous data types
# - indexing ans slicing is possible

# %%
student_mark = 67,78,10,100,90

# %%
student_mark
# Out:
# (67, 78, 10, 100, 90)

# %%
type (student_mark)
# Out:
# tuple

# %%
empty_cart = []

# %%
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
items_to_buy = ["Apple","Orange","Graphes","Gauva","Apple"]
items_to_buy
# Out:
# ['Apple', 'Orange', 'Graphes', 'Gauva', 'Apple']

# %%
items_to_buy = ["Apple","Orange","Graphes","Gauva","Apple",6.75,10]
items_to_buy
# Out:
# ['Apple', 'Orange', 'Graphes', 'Gauva', 'Apple', 6.75, 10]

# %%
# slicing is done by index start from 0, using the len function return the number of items in a contains

# %%
len(items_to_buy)
# Out:
# 7

# %%
items_to_buy[0] # indexing
# Out:
# 'Apple'

# %%
items_to_buy[0:2] # start = 0, end = len+1 always use -> data is start to end index -1 , this concept called as range of valuse
# Out:
# ['Apple', 'Orange']

# %%
items_to_buy[-3] # negative indexing is also positive -> traverse from right to left
# Out:
# 'Apple'

# %%
items_to_buy[2:6]
# Out:
# ['Graphes', 'Gauva', 'Apple', 6.75]

# %%
items_to_buy[-7:-4] # end : start
# Out:
# ['Apple', 'Orange', 'Graphes']

# %%
#changing the values in future
items_to_buy[1] = "Watermelon" # this process is called mutable

# %%
items_to_buy
# Out:
# ['Apple', 'Watermelon', 'Graphes', 'Gauva', 'Apple', 6.75, 10]

# %% [markdown]
# ## Sets
# - set does not allow duplicates
# - 1D
# - it is hetergenous
# - indexing and Slicing is not possible

# %%
secret_values = 723,234,234.234

# %%
secret_values
# Out:
# (723, 234, 234.234)

# %%
empty_cart2 = set()

# %%
empty_cart2
# Out:
# set()

# %%
type(empty_cart2)
# Out:
# set

# %%
items_to_buy2 = {"Apple","Orange","Graphes","Gauva","Apple",23}
items_to_buy2 # set does not allow duplicates && it is one-dimensional && it is hetergenous
# Out:
# {23, 'Apple', 'Gauva', 'Graphes', 'Orange'}

# %%
items_to_buy2[2] # 'set' object is not subscriptable -> means that indexing and Slicing is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 items_to_buy2[2]
#
# TypeError: 'set' object is not subscriptable

# %%
# how set is mutable?
# adding an element
items_to_buy2.add("banana")

#removing an element
items_to_buy2.discard("Graphes")

# %%
items_to_buy2
# Out:
# {23, 'Apple', 'Gauva', 'Orange', 'Watermelon', 'banana'}
