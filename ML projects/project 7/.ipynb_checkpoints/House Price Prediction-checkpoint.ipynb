# %% [markdown]
# # House price prediction using Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Load dataset

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset
# Out:
#        area   price
# 0      8450  208500
# 1      9600  181500
# 2     11250  223500
# 3      9550  140000
# 4     14260  250000
# ...     ...     ...
# 1455   7917  175000
# 1456  13175  210000
# 1457   9042  266500
# 1458   9717  142125
# 1459   9937  147500
#
# [1460 rows x 2 columns]

# %% [markdown]
# # Summarize dataset

# %%
print(dataset.shape)
print(dataset.head(5))
# Out:
# (1460, 2)
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %% [markdown]
# # Visualize Dataset

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(dataset.area,dataset.price,color='red',marker='*')

# %% [markdown]
# # Segregate Dataset into input x and output y

# %%
X = dataset.drop('price',axis='columns')

# %%
X
# Out:
#        area
# 0      8450
# 1      9600
# 2     11250
# 3      9550
# 4     14260
# ...     ...
# 1455   7917
# 1456  13175
# 1457   9042
# 1458   9717
# 1459   9937
#
# [1460 rows x 1 columns]

# %%
Y = dataset.price
Y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: price, Length: 1460, dtype: int64

# %% [markdown]
# # Training dataset using Linear Regression

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict prices for Land sq.Feet of custom values

# %%
x = 40000
LandAreainSqFt[[x]]
PredictedmodelResult = model.predict(LandAreainSqFt)
print(PredictedmodelResult)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 x = 40000
# ----> 2 LandAreainSqFt[[x]]
#       3 PredictedmodelResult = model.predict(LandAreainSqFt)
#       4 print(PredictedmodelResult)
#
# NameError: name 'LandAreainSqFt' is not defined

# %% [markdown]
# # Y = m*X+b

# %%
# Coefficient - m
m = model.coef_
print(m)
# Out:
# [2.09997195]

# %%
# intercept -b
b = model.intercept_
print(b)
# Out:
# 158836.1518968766

# %%
y = m*x+b
print("The price of {0} Square feet Land is: {1}".format(x,y[0]))
# Out:
# The price of 40000 Square feet Land is: 242835.02996518355
